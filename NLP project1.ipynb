# %%
# !pip install nltk

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
paragraph =" he is good boy.she is a good girl.boy and girlare good."
paragraph
# Out:
# ' he is good boy.she is a good girl.boy and girlare good.'

# %%
#tokenization

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
words = nltk.word_tokenize(paragraph)

# %%
# stopwords removes grammer

# %%
from nltk.corpus import stopwords
stopwords.words('English')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
paragraph
# Out:
# ' he is good boy.she is a good girl.boy and girlare good.'

# %%
import re #regular expression
corpus = []
for i in range (len(sentences)):
    print(i)
    rp=re.sub('[^ a - Z A - Z]'," ",sentences[i])
    rp=rp.lower()
    rp=rp.upper()
    rp=rp.split()
# Out:
# 0

# %%
rp=[word for word in rp if not word in set(stopwords.words('English'))]
rp=" ".join(rp)
corpus.append(rp)
print (corpus)
# Out:
# ['A A A']

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus=['A A A']
vectorizer = CountVectorizer(token_pattern=r'(?u)\b\w+\b')
x=vectorizer.fit_transform(corpus).toarray()
print(x)
df=pd.DataFrame(x,columns=['boy'])
df
# Out:
# [[3]]
#    boy
# 0    3

# %%
import pandas as pd
import numpy as np

# %%
df
# Out:
#    boy
# 0    3
